# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
#
# <h1> Chapter 5: Home wet home! </h1>
#
# <img src="./visual_arts/230217_trappist_1a.jpg" width="100%">
#
# <p style='text-align: justify;'>
#
# We were searching for a planet not too hot, not too cold, just right to support liquid water.
#
# HAL immediately displayed the Distance-Temperature diagram on my screen.
#
# I just had to identify the region around the star at which the temperature is larger than the freezing point (0$^\circ$) and smaller than the boiling point of water (100$^\circ$). HAL told me that the temperature was reported in Kelvin (K) instead of degree-Celsius ($^\circ$). However, it was easy to switch from [$^\circ$] to [K]. If I knew the temperature in [$^\circ$], I only had to add 273 to get the temperature in [K].
#
# The astrojet was running out of fuel faster than expected and we had to hurry up.
#
# I immediately started looking at the diagram and tried to find the right planet.
#
# <h1> It's your turn now!</h1>
#
# Now you have to find the habitable zone around the Sun. This is the region around a star in which there exists liquid water on the surface of a planet.
#
# Have a look at the Distance-Temperature diagram and find the boundaries of the habitable zone.
#
# Thereafter, enter the distance-values in the slider and plot the habitable zone.
#
# Which planets are in the habitable zone?
#
#
#
# <h1> Bakgrund </h1>
# <p>
# Ett villkor för att hitta liv på en planet, är att planeten existerar i en så kallad beboelig zon (habitable zone).
# </p>
#
# <p>
# En beboelig zon i ett solsystem (dvs. planeterna kring en stjärna) uppstår i det avståndet som vatten kan finnas i flytande form.
# </p>
#
# <p>
# På jorden (som då existerar i den beboeliga zonen kring solen) har vi just sådana temperaturer, vilket har möjliggjort för liv att uppstå.
# </p>
#
# <h1> Instruktioner</h1>
# <p>
# Den sista uppgiften går ut på att bestämma vilka planeter som befinner sig i den beboeliga zonen för solsystemet vi har färdats till.
# </p>
#
# <p>
# Du behöver bestämma mellan vilka avstånd som den beboeliga zonen uppstår i genom temperatur-avståndsfiguren som finns nedanför.
# </p>
#
# <p>
# Sedan ändra värdena i mätaren nedanför till de avståndena.
# </p>
#
# <p>
# Kan du bestämma vilka planeter som finns innanför zonen?
# </p>
#
# <p>
# Tips: Bestäm först vilka temperaturer som ingår i den beboeliga zonen innan du läser av vilka avstånd som är möjliga!
# </p>
# </div>

# %%
from IPython.display import display
from ipywidgets import widgets
import numpy as np
from IPython.display import clear_output
import matplotlib.pylab as plt
from src.support import *
import warnings
warnings.filterwarnings("ignore")

plt.style.use('seaborn-ticks')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

planet_temperature(Lstar=Lsun)

# %%
from IPython.display import display
from ipywidgets import widgets
import numpy as np
from IPython.display import clear_output
import matplotlib.pylab as plt
from src.support import *

plt.style.use('seaborn-ticks')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'





slider = widgets.FloatRangeSlider(min = 0.3, max = 6, description = 'Distance (AU)')
display(slider)
print('You can enter the values in the box on the side of the slider - press Enter to submit the values before plotting!')
button = widgets.Button(description="Plot zone")
display(button)
plot_hz(0,0)

def on_button_click(b):
    d_lower = slider.value[0]
    d_upper = slider.value[1]
    clear_output()
    print('You can enter the values to the box in the side of the slider - press Enter to submit the values before plotting!')
    display(slider)
    display(button)
    plot_hz(d_lower,d_upper)
    
    

T_lower = 373 #K
T_upper = 273 #K

d_lower = np.sqrt(Lsun/(4.*np.pi*sigmaSB*T_lower**4))/AU
d_upper = np.sqrt(Lsun/(4.*np.pi*sigmaSB*T_upper**4))/AU


button.on_click(on_button_click)
# Out:
# You can enter the values to the box in the side of the slider - press Enter to submit the values before plotting!
# A Jupyter Widget
# A Jupyter Widget

# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
# <p style='text-align: justify;'>
#
# With wildly flashing warning lights HAL managed to land the astrojet on the interstellar astroport on planet Earth close to New Sigtuna. Flight control was surprised to see my unscheduled astrojet arriving. As you can imagine this caused considerable excitement at the astroport.
#
# They were astonished to hear that despite my young age I understood the principles of astrophysics and that I was able to safely navigate through the galaxy. I had to explain and repeat my story many times for hours, when I suddenly heard a familiar voice behind me.
#
# My friend had followed the news coverage on my landing broadcasted to all mobile communicators and decided to immidiately pick me up at the astroport.
#
# Finally, my journey came to an end. My friend and I were so excited about this adventure that we decided to go to the University together and study physics!
#
# Oh, how lucky we were, because just during those days, Stockholm University was organising a big outreach event, Forskarfredag and Fysikumfest, for people like us.
#
# Can you believe it? We went there and we liked the place so much that we decided to stay. This is how I became a student in physics and then afterwards a researcher!</p>
#
# <h1> It's your turn now!</h1>
#
# Go out and search for new mysteries of the Universe to start your own adventure ...

# %% [markdown]
# <div class="alert alert-block alert-danger" markdown="1">
#
# <h1> Summary: What have we learned? </h1>
#
#
#
# <ol>
# <li> <p>Human life doesn't exist everywhere in our solar system. The so-called habitable zone occupies a narrow window around the Sun.</p></li>
# <li> <p>The main condition for human life to exist is the liquid water is available.</p></li>
# <li> <p>This imposes a condition on the surface temperature of possible planets in the habitable zone:
#
# \begin{equation}
# T_\mathrm{ice}\le T \le T_\mathrm{vapor}
# \end{equation}</p></li>
# <li> <p>By imposing this condition to the equation of energy conservation derived in the previous Chapter, we can derive the distance to the star and select the habitable zone around the Sun.</p></li>
# </ol>
#
#
# </div>
#
#
# <div class="alert alert-block alert-info" markdown="1">
#
# <h1> If you want to learn more: The condition for human life to exist: liquid water </h1>
#
# <p style='text-align: justify;'>
# One of the most fascinating questions of modern science concerns the emergence of life and where to find it in the galaxy. According to our current understanding, the most important requirement to sustain life is liquid water. This is the reason why scientists are interested in searching for environments in the Universe that can provide liquid water. In particular, at planets, the presence of liquid water depends on many environmental conditions like the temperature and pressure of the atmosphere. The main driver of the surface temperature of a planet, however, is the central star, around which the planet orbits at some distance.</p>
#
# <p style='text-align: justify;'>
# At least on Earth liquid water is essential to the existence of life. For this reason regions around stars that permit surface temperatures between 273 K, the melting point of water, and 373 K, the boiling point of water, are called habitable zones. The proposed definition of a habitable zone thus is clearly based on the hypothesis that extraterrestrial life shares this requirement.</p>
#
# The simple laws of blackbody radiation permit us to derive remarkably simple relations between the Temperature of a star $T_{\star}$, its size $R_{\star}$ and the temperature of a planet $T_p$ orbiting at a distance $R_p$ from the center of the stellar system:
# \begin{eqnarray}
# T_p &=& T_{\star}\,\sqrt{\frac{R_{\star}}{2 \, R_p}} \, .
# \end{eqnarray}
#
# This simple equation provides a good start for investigating the question of where to find life in the Universe.
#
# Realistic models of planetary temperatures need to account for more details. In particular, Earth climate is determined by an atmosphere and also the albedo of a planet plays a crucial role. The albedo of a planet determines how much starlight will be reflected and how much of it will be thermalized at the planet's surface and converted to heat. A crucial part of the Earth's albedo is the enormous white icefields at the poles which reflect sunlight into space and prevent that Earth will heat too much. On the other hand molecules in the atmosphere will prevent that the Earth emits too much thermal radiation and cools too quickly. The latter effect is also called the greenhouse effect and is related to the discussion on the topic of global climate change. All these effects determine the balance between absorbed and emitted energy and are crucially determining the habitability of planets.
# <h2> Literature </h2>
#
# <ol>
# <li> <p>Habitable zone <a href="https://arxiv.org/pdf/1708.09766.pdf">
# https://arxiv.org/pdf/1708.09766.pdf</a>.</p></li>
# <li> <p>Kepler Habitable Planets <a href="https://www.nasa.gov/image-feature/ames/kepler/kepler-habitable-zone-planets">
# https://www.nasa.gov/image-feature/ames/kepler/kepler-habitable-zone-planets</a>.</p></li>
# <li> <p> <a href="http://www.public.asu.edu/~hhuang38/mae578_lecture_03.pdf">
# http://www.public.asu.edu/~hhuang38/mae578_lecture_03.pdf</a>.</p></li>
# </ol>
#
#
#
# </div>

# %%
import warnings
warnings.filterwarnings("ignore")

from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
# Out:
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
