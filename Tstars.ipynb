# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
# <h1> Chapter 2: Twinkle twinkle little star</h1>
#
#
# <img src="./visual_arts/potw1521a.jpg" width="80%">
#
#
# <p style='text-align: justify;'>
#
# I was amazed. HAL helped me to discover the universal law of Wien's displacement of peak wavelength with temperature.
#
# This fundamental law applies to all warm bodies, including the star I was searching for.
#
# As I was finished with inputting the data from the Planck spectra, HAL said: 'Lani, you're close to the real relationship, let me help you'
#
# HAL drew a line which represented Wien's law. HAL added that real-life measurements always have an error associated with the values and that my estimates are well within the errors.
#
# All I needed to do is to measure spectra of stars and find the wavelength at its maximum. Wien's displacement law would then tell me the temperature of the star.
#
# Quickly, I switched on the sensor system of my astrojet. The integrated spectrograph instantly measured the spectra of all stars surrounding us. HAL started processing. After a while HAL returned with an answer:
#
# 'Lani, based on the astrotrain path you were on, I have identified three stellar candidate systems where your friend may live. But my central processing unit is overheated and I cannot determine their exact temperatures!'
#
# I got excited one of these stars might be my friends new home. Maybe I could use Wien's displacement law to determine the temperature of these stars by myself.
#
# On the screen infront of me HAL displayed my measurements of Wien's displacement together with the line HAL added. Thanks HAL!
# </p>
#
# <h2> It's your turn now! </h2>
#
# You will now be provided three stellar spectra. Your goal is to determine the temperature of those stars.
# Find the wavelength at the peak and use your plot of Wien's displacement to determine the stellar temperatures.
#
# Enter these values in the boxes below the images to see if you have a correct answer or not.
#
# <p>When you are done with this task, go to <a href="hr.ipynb">
# [Chapter 3]</a>.</p>
#
#
# <h1> Bakgrund </h1>
# Vår galax Vintergatan (engelska Milky Way) har ca 100-400 miljarder stjärnor, alla med olika storlekar och temperaturer. Vi vet sedan tidigare att stjärnor med olika temperaturer har olika färger. Genom att studera ljuset från stjärnorna, sedan bestämma högsta våglängden kan vi ta reda på temperaturen hos respektive stjärna - låt oss göra det nu!
#
# <h1> Instruktioner </h1>
# Observera spektruma nedanför. Använd grafen från förra kapitlet (den som visar sambandet mellan temperaturen och våglängden) för att placera stjärnornas våglängder däri.
#
# Skriv in värdena för temperaturerna du läser av i svarsrutorna nedanför varje stjärna.
#
# Vilka temperaturer har stjärnorna?

# %%
from src.support import *
plt.style.use('seaborn-ticks')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plot_solution_wien_displacement()

# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
# <h3>  Measure the temperature of  object nr. 1 </h3>
#
#
# <img src="./visual_arts/SOHO_image_of_the_Sun_node_full_image_2.gif" width="40%">
#
# <p style='text-align: justify;'>
# Object nr.1 is a good representation of how our Sun looks like. The Sun is the star at the center of our stellar system, the Solar System. It is almost 5 billion years old and you could consider it as a middle-age star. The Sun is 150 million km far from the Earth. Therefore, it takes 8 minutes for the light emitted by the Sun to arrive on Earth. Just take a second to think of it: when you look at the Sun (beware! With proper eye-protections!), the image you observe is a picture of the Sun as it was 8 minutes earlier. The ancient Greek name of the Sun was Helios. It is not a coincidence that one of the most abundant chemical elements inside the Sun has been named helium.
# </p>
#
# <p style='text-align: justify;'>
# In the following you should use this spectrum and the results of the Wien's displacement law to estimate the temperature of the Sun.
# </p>
#
# </div>

# %%
wavelength,intensity=plot_data_spec(1)

#Temperature input
from IPython.display import display
from ipywidgets import widgets
import numpy as np
from IPython.display import clear_output

print('Enter the value of the temperature of the star (Kelvin)')
print('Press Enter to submit your input')
text1 = widgets.Text()
display(text1)
outtxt=''
def handle_submit1(sender):
    number = float(text1.value)
    
    if np.fabs(number - 5780.)<100:
        outtxt= 'Correct! The temperature of the first star is 5780 Kelvin.'
        text1.close()
    else:
        outtxt= 'Incorrect'  
    print('                                           ', end="\r")
    print(outtxt, end="\r")   
    
text1.on_submit(handle_submit1)
# Out:
# Enter the value of the temperature of the star (Kelvin)
# Press Enter to submit your input
# Text(value='')

# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
# <h3>  Measure the temperature of  object nr. 2 </h3>
#
# <img src="./visual_arts/heic0516e.jpg" width="40%">
#
# <p style='text-align: justify;'>
# Object nr.2 is a good approximation of how Sirius looks like. Sirius (also called α CMa according to the Bayer designation) is a star in the constellation Canis Major to the left and below Orion. Its name comes from ancient Greek meaning “glowing” or “scorcher.” Sirius is the brightest star in the night sky. This is not surprising since, with a distance of only nine lightyears from Earth, Sirius is one the closest stars to us in the Universe. While the naked eye perceives Sirius as a single star, investigation with telescopes reveal that Sirius is a binary star system consisting of a bright white star, named Sirius A, accompanied by a faint white dwarf, called Sirius B (α CMa B). Sirius A (α CMa A) is about two times more massive and 25 times more luminous than our Sun.
# </p>
#
# </br>
# <p style='text-align: justify;'>
# In the following you should use this spectrum and the results of the Wien's displacement law to estimate the temperature of Sirius.
# </p>
#
# </div>

# %%
wavelength,intensity=plot_data_spec(2)

#Temperature input
from IPython.display import display
from ipywidgets import widgets
import numpy as np
from IPython.display import clear_output

print('Enter the value of the temperature of the star (Kelvin)')
print('Press Enter to submit your input')
text2 = widgets.Text()
display(text2)
outtxt=''
def handle_submit2(sender):
    number = float(text2.value)
    
    if np.fabs(number - 6330.)<100:
        outtxt= 'Correct! The temperature of the second star is 6330 Kelvin.'
        text2.close()
    else:
        outtxt= 'Incorrect'  
    print('                                           ', end="\r")
    print(outtxt, end="\r")   
    
text2.on_submit(handle_submit2)
# Out:
# Enter the value of the temperature of the star (Kelvin)
# Press Enter to submit your input
# Text(value='')

# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
# <h3> Measure the temperature of  object nr. 3 </h3>
#
#
# <img src="./visual_arts/opo9726c.jpg" width="40%">
#
# <p style='text-align: justify;'>
# Object nr.3 is a good representation of how Alpha Centauri C looks like. Alpha Centauri C is one of the three stars forming the closest stellar system to the Sun, located in the southern sky in the Centaurus constellation. The three stars are trivially labeled A, B, and C. Alpha Centauri A and B form a binary system, called AB. Alpha Centauri C is much farther away, but when viewed from Earth, it forms a visual binary system with AB. Alpha Centauri C is also the closest star to the Sun, therefore also called Proxima Centauri. The distance between Proxima Centauri and the Sun is 13 thousand times longer than the distance between Earth and the Sun. If we travelled at light-speed, it would take us almost two month and a half to reach Proxima Centauri.
# </p>
#
# <p style='text-align: justify;'>
# In the following you should use this spectrum and the results of the Wien's displacement law to estimate the temperature of Proxima Centauri.
# </p>
#
# </div>

# %%
wavelength,intensity=plot_data_spec(3)

#Temperature input
from IPython.display import display
from ipywidgets import widgets
import numpy as np
from IPython.display import clear_output

print('Enter the value of the temperature of the star (Kelvin)')
print('Press Enter to submit your input')
text3 = widgets.Text()
display(text3)
outtxt=''
def handle_submit3(sender):
    number = float(text3.value)
    
    if np.fabs(number - 3780.)<100:
        outtxt= 'Correct! The temperature of the third star is 3780 Kelvin.'
        text3.close()
    else:
        outtxt= 'Incorrect'  
    print('                                           ', end="\r")
    print(outtxt, end="\r")   
    
text3.on_submit(handle_submit3)
# Out:
# Enter the value of the temperature of the star (Kelvin)
# Press Enter to submit your input
# Text(value='')

# %% [markdown]
# <div class="alert alert-block alert-success" markdown="1">
#
# <p>Now go to <a href="hr.ipynb">
# [Chapter 3]</a>.</p>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" markdown="1">
#
# <h1> Summary: What have we learned? </h1>
#
# <ol>
# <li> <p>The spectrum of the radiation emitted by stars is an approximate black-body spectrum. </p></li>
# <li> <p>Our galaxy -- the Milky Way -- contains around 100-400 billion stars.</p></li>
# <li> <p>Different types of stars exist. In particular, different types exhibit different temperatures. This means that they emit different black-body spectra. By measuring the black-body spectrum of a star, one can determine the star's temperature accordingly to Wien's displacement law.</p></li>
# </ol>
#
# <p><a href="hr.ipynb">
# [Chapter 3]</a>.</p>
#
# </div>
#
#
# <div class="alert alert-block alert-info" markdown="1">
#
# <h1>  If you want to learn more: Stars - lighthouses of the galaxy </h1>
#
# <p style='text-align: justify;'>
# There are billions of stars in our galaxy, the Milky Way. In particular, our Sun is a medium-sized star. Each of the stars in the galaxy can be considered as an enormous ball of very hot gaseous plasma. Stars are born in so-called star-forming regions consisting of large clouds of hydrogen and a bit of helium gas. These clouds collapse due to their own gravity leading to heating of the gas. Once the gas reaches sufficiently high temperatures nuclear fusion processes are ignited. These nuclear processes produce enormous amounts of heat and radiation and thus a new star is born. Stars can exist for billions of years until they run out of fuel. During their final stages, stars become giants by expanding to enormous sizes, while their cores contract. Eventually, these stars explode and turn into dim, cold objects like black dwarfs, neutron stars or black holes, depending on their initial mass. Generally, the most massive stars have the shortest lifespan. More massive stars burn hotter and faster than their lighter counterparts like our Sun.
# </p>
#
# These stars create almost all of the visible light in our galaxy.
#
# <img src="./visual_arts/ESA_Gaia_DR2_AllSky_Brightness_Colour_black_bg_625.jpg" width="50%">
#
# <p style='text-align: justify;'>
# This emitted stellar light tells a story about each star. Ever since the beginning of Astronomy, researchers have used this observed star light to conclude on properties of the emitting stars, like their masses, temperatures, sizes and luminosities.
# </p>
#
# <h2> Measuring stellar temperatures </h2>
#
# <p style='text-align: justify;'>
# The spectrum of emitted electromagnetic radiation of stars follows approximately the Planck law superimposed by additional spectral absorption features of atoms in the cooler outer stellar atmospheres. Both features, the continuum emission as well as spectral absorption lines are dependent on temperature. Consequently, the light we receive from distant stars provides us with significant information on their temperatures.
# </p>
#
# <p style='text-align: justify;'>
# However, temperatures of stars cannot be measured directly and thus we will extract such information from the continuum black body radiation. In particular, we may use Wien's displacement law, as derived above, to simply relate the peak wavelength of the observed spectrum to the temperature of a star.
# </p>
#
# <p style='text-align: justify;'>
# Wien himself used his relation to estimate the effective temperature of the Sun. The significance of Wien's law is that if you can measure the peak wavelength from a spectrum, then you can use it to estimate the effective temperature.
# </p>
#
#
# <h2> Literature </h2>
#
# <ol>
# <li> <p>The Keppler mission has found hundreds of planets in the habitable zone <a href="http://sci.esa.int/education/48986-blackbody-radiation/">
# http://sci.esa.int/education/48986-blackbody-radiation/</a>.</p></li>
# <li> <p>A more graphical description <a href="http://hyperphysics.phy-astr.gsu.edu/hbase/wien.html">
# http://hyperphysics.phy-astr.gsu.edu/hbase/wien.html</a>.</p></li>
# <li> <p>Some notes on Black Body Radiation <a href="http://www.csc.kth.se/~cgjoh/ambsblack.pdf">
# http://www.csc.kth.se/~cgjoh/ambsblack.pdf</a>.</p></li>
# </ol>
#
#
#
# <p><a href="hr.ipynb">
# [Chapter 3]</a>.</p>
#
# </div>

# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
#
#
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
# Out:
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
#
#
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
